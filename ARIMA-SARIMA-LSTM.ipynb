# %% [markdown]
# <a href="https://colab.research.google.com/github/anthng/time-series-forecasting/blob/main/ARIMA-SARIMA-LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import urllib.request, json
import os
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

try:
    from statsmodels.tsa.arima.model import ARIMA
    import pmdarima as pm
except:
    # !pip3 install pmdarima
    # !pip3 install 'statsmodels==0.12.1'
    from statsmodels.tsa.arima.model import ARIMA
    import pmdarima as pm

import statsmodels.api as sm

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anthng/time-series-forecasting/main/disease_vn.csv', parse_dates=[0])[['date1', 'diarrhoea']]
df['date1'] = pd.to_datetime(df["date1"].dt.strftime('%Y-%m-%d'))
df = df.drop_duplicates('date1')

df = df.sort_values('date1')
df
# Out:
#            date1  diarrhoea
# 0     1997-01-15        827
# 55    1997-02-15       1513
# 108   1997-03-15       2335
# 160   1997-04-15       1313
# 213   1997-05-15       3161
# ...          ...        ...
# 12767 2016-09-15        286
# 12822 2016-10-15        224
# 12877 2016-11-15        223
# 12932 2016-12-15        200
# 12986 2017-01-15        993
#
# [241 rows x 2 columns]

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),(df['diarrhoea']))
plt.xticks(range(0,df.shape[0],12),df['date1'].loc[::12],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Diarrhoea',fontsize=18)
plt.show()

# %%
df['diarrhoea'].describe()
# Out:
# count     241.000000
# mean     1558.236515
# std      1552.718309
# min       182.000000
# 25%       420.000000
# 50%       898.000000
# 75%      2335.000000
# max      7385.000000
# Name: diarrhoea, dtype: float64

# %%
df_clean = df.set_index('date1')
n = int(df_clean.shape[0]*0.6)
train_df = df_clean[:n][['diarrhoea']]
test_df = df_clean[n:][['diarrhoea']]


train = train_df
scalers={}
for i in train_df.columns:
    scaler = MinMaxScaler(feature_range=(-1,1))
    s_s = scaler.fit_transform(train[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+ i] = scaler
    train[i]=s_s

test = test_df
for i in train_df.columns:
    scaler = scalers['scaler_'+i]
    s_s = scaler.transform(test[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+i] = scaler
    test[i]=s_s

# %% [markdown]
# # Training

# %% [markdown]
# # ARIMA

# %%
arima_model = pm.auto_arima(train, start_p=0, start_q=0, max_p=10, max_q=10, start_P=0, start_Q=0, max_P=10, max_Q=10, m=12, stepwise=True, seasonal=False, information_criterion='aic', trace=True, d=1, D=1, error_action='warn', suppress_warnings=True, random_state = 2021, n_fits=30)
# Out:
# /usr/local/lib/python3.6/dist-packages/pmdarima/arima/_validation.py:62: UserWarning: m (12) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=61.189, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=46.301, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=43.552, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=59.189, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=45.549, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=45.549, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=47.466, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=41.560, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=43.557, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=43.557, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=44.303, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=45.472, Time=0.15 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.018 seconds

# %%
test_arima = test.copy()
train_arima = train.copy()

history = [x for x in train_arima.values]
predictions = list()
# walk-forward validation
for t in range(len(test_arima)):
	model = ARIMA(history, order=(0,1,1))
	arima_results = model.fit()
	output = arima_results.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test_arima.iloc[t]
	history.append(obs)
	# print('predicted=%f, expected=%f' % (yhat, obs))
 
predictions = np.array(predictions)

# %%
test_arima['pred'] = predictions
test_arima['y_diarrhoea'] = scaler.inverse_transform(test_arima.diarrhoea.values.reshape(-1,1))
test_arima['y_pred'] = scaler.inverse_transform(test_arima.pred.values.reshape(-1,1))
test_arima
# Out:
#             diarrhoea      pred  y_diarrhoea      y_pred
# date1
# 2009-01-15  -0.903025 -0.921909        654.0  587.207229
# 2009-02-15  -0.964942 -0.910303        435.0  628.257480
# 2009-03-15  -0.914900 -0.943878        612.0  509.502675
# 2009-04-15  -0.842805 -0.926073        867.0  572.479130
# 2009-05-15  -0.569975 -0.874912       1832.0  753.434564
# ...               ...       ...          ...         ...
# 2016-09-15  -1.007068 -0.994856        286.0  329.192836
# 2016-10-15  -1.024597 -1.002310        224.0  302.831242
# 2016-11-15  -1.024880 -1.015913        223.0  254.716337
# 2016-12-15  -1.031383 -1.021386        200.0  235.357556
# 2017-01-15  -0.807181 -1.027488        993.0  213.776394
#
# [97 rows x 4 columns]

# %%
y_forecasted = test_arima.y_pred.values
y_truth = test_arima.y_diarrhoea.values


# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of ARIMA is {}'.format(mse))
test_arima[['y_diarrhoea', 'y_pred']].plot(title='ARIMA',figsize=(15,9))
plt.xlabel("Date")
plt.ylabel("Diarrhoea")
plt.show()
# Out:
# The Mean Squared Error of ARIMA is 32496.536599414518

# %% [markdown]
# # SARIMA

# %%
sarima_model = pm.auto_arima(train, start_p=0, start_q=0, max_p=10, max_q=10, start_P=0, start_Q=0, max_P=10, max_Q=10, m=12, stepwise=True, seasonal=True, information_criterion='aic', trace=True, d=1, D=1, error_action='warn', suppress_warnings=True, random_state = 2021, n_fits=20)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=140.682, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=84.122, Time=0.13 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.67 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=110.826, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=66.918, Time=0.37 sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=59.756, Time=1.00 sec
#  ARIMA(1,1,0)(4,1,0)[12]             : AIC=57.687, Time=1.94 sec
#  ARIMA(1,1,0)(5,1,0)[12]             : AIC=58.229, Time=2.81 sec
#  ARIMA(1,1,0)(4,1,1)[12]             : AIC=inf, Time=7.91 sec
#  ARIMA(1,1,0)(3,1,1)[12]             : AIC=54.039, Time=3.15 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=1.39 sec
#  ARIMA(1,1,0)(3,1,2)[12]             : AIC=inf, Time=2.63 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=inf, Time=2.37 sec
#  ARIMA(1,1,0)(4,1,2)[12]             : AIC=58.039, Time=5.57 sec
#  ARIMA(0,1,0)(3,1,1)[12]             : AIC=inf, Time=3.52 sec
#  ARIMA(2,1,0)(3,1,1)[12]             : AIC=54.760, Time=4.11 sec
#  ARIMA(1,1,1)(3,1,1)[12]             : AIC=54.129, Time=3.23 sec
#  ARIMA(0,1,1)(3,1,1)[12]             : AIC=53.093, Time=3.66 sec
#  ARIMA(0,1,1)(2,1,1)[12]             : AIC=51.107, Time=0.96 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=inf, Time=0.79 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=64.903, Time=0.44 sec
#  ARIMA(0,1,1)(2,1,2)[12]             : AIC=53.098, Time=2.21 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=83.745, Time=0.12 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=1.58 sec
#  ARIMA(0,1,1)(3,1,0)[12]             : AIC=57.401, Time=1.00 sec
#  ARIMA(0,1,1)(3,1,2)[12]             : AIC=55.089, Time=1.85 sec
#  ARIMA(0,1,0)(2,1,1)[12]             : AIC=inf, Time=1.42 sec
#  ARIMA(1,1,1)(2,1,1)[12]             : AIC=52.129, Time=1.45 sec
#  ARIMA(0,1,2)(2,1,1)[12]             : AIC=52.231, Time=1.36 sec
#  ARIMA(1,1,2)(2,1,1)[12]             : AIC=53.751, Time=2.00 sec
#  ARIMA(0,1,1)(2,1,1)[12] intercept   : AIC=52.829, Time=1.71 sec
#
# Best model:  ARIMA(0,1,1)(2,1,1)[12]
# Total fit time: 61.429 seconds

# %%
import statsmodels.api as sm

del history
test_sarima = test.copy()
train_sarima = train.copy()

history = [x for x in train_sarima.values]
predictions = list()

for t in range(len(test_sarima)):
	model = sm.tsa.statespace.SARIMAX(history,order=(0,1,1), seasonal_order=(2, 1, 1, 12))
 
	sarima_results = model.fit(max_iter=200, method='powell')
	output = sarima_results.forecast()
	yhat = output[0]
	predictions.append(yhat)
 
	obs = test_sarima.iloc[t]
	history.append(obs)

	# print('predicted=%f, expected=%f' % (yhatpredictions = np.array(predictions)
predictions = np.array(predictions)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.142736
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: 0.140849
#          Iterations: 8
#          Function evaluations: 515
# Optimization terminated successfully.
#          Current function value: 0.139027
#          Iterations: 8
#          Function evaluations: 514
# Optimization terminated successfully.
#          Current function value: 0.136051
#          Iterations: 8
#          Function evaluations: 547
# Optimization terminated successfully.
#          Current function value: 0.132658
#          Iterations: 8
#          Function evaluations: 518
# Optimization terminated successfully.
#          Current function value: 0.132929
#          Iterations: 8
#          Function evaluations: 519
# Optimization terminated successfully.
#          Current function value: 0.137009
#          Iterations: 7
#          Function evaluations: 461
# Optimization terminated successfully.
#          Current function value: 0.133517
#          Iterations: 7
#          Function evaluations: 464
# Optimization terminated successfully.
#          Current function value: 0.130299
#          Iterations: 8
#          Function evaluations: 523
# Optimization terminated successfully.
#          Current function value: 0.126876
#          Iterations: 8
#          Function evaluations: 526
# Optimization terminated successfully.
#          Current function value: 0.123522
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: 0.120287
#          Iterations: 8
#          Function evaluations: 521
# Optimization terminated successfully.
#          Current function value: 0.117113
#          Iterations: 7
#          Function evaluations: 456
# Optimization terminated successfully.
#          Current function value: 0.114176
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: 0.111150
#          Iterations: 8
#          Function evaluations: 523
# Optimization terminated successfully.
#          Current function value: 0.107998
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: 0.104668
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: 0.101460
#          Iterations: 7
#          Function evaluations: 464
# Optimization terminated successfully.
#          Current function value: 0.098572
#          Iterations: 7
#          Function evaluations: 463
# Optimization terminated successfully.
#          Current function value: 0.095430
#          Iterations: 8
#          Function evaluations: 533
# Optimization terminated successfully.
#          Current function value: 0.092268
#          Iterations: 7
#          Function evaluations: 461
# Optimization terminated successfully.
#          Current function value: 0.089099
#          Iterations: 7
#          Function evaluations: 457
# Optimization terminated successfully.
#          Current function value: 0.085994
#          Iterations: 7
#          Function evaluations: 459
# Optimization terminated successfully.
#          Current function value: 0.082827
#          Iterations: 7
#          Function evaluations: 457
# Optimization terminated successfully.
#          Current function value: 0.080098
#          Iterations: 7
#          Function evaluations: 462
# Optimization terminated successfully.
#          Current function value: 0.077323
#          Iterations: 7
#          Function evaluations: 458
# Optimization terminated successfully.
#          Current function value: 0.074842
#          Iterations: 7
#          Function evaluations: 449
# Optimization terminated successfully.
#          Current function value: 0.071714
#          Iterations: 7
#          Function evaluations: 454
# Optimization terminated successfully.
#          Current function value: 0.068597
#          Iterations: 7
#          Function evaluations: 451
# Optimization terminated successfully.
#          Current function value: 0.065514
#          Iterations: 7
#          Function evaluations: 452
# Optimization terminated successfully.
#          Current function value: 0.062521
#          Iterations: 7
#          Function evaluations: 447
# Optimization terminated successfully.
#          Current function value: 0.059777
#          Iterations: 7
#          Function evaluations: 447
# Optimization terminated successfully.
#          Current function value: 0.056866
#          Iterations: 7
#          Function evaluations: 448
# Optimization terminated successfully.
#          Current function value: 0.054092
#          Iterations: 7
#          Function evaluations: 458
# Optimization terminated successfully.
#          Current function value: 0.051092
#          Iterations: 7
#          Function evaluations: 458
# Optimization terminated successfully.
#          Current function value: 0.048184
#          Iterations: 7
#          Function evaluations: 459
# Optimization terminated successfully.
#          Current function value: 0.045362
#          Iterations: 7
#          Function evaluations: 451
# Optimization terminated successfully.
#          Current function value: 0.042447
#          Iterations: 7
#          Function evaluations: 459
# Optimization terminated successfully.
#          Current function value: 0.039596
#          Iterations: 7
#          Function evaluations: 455
# Optimization terminated successfully.
#          Current function value: 0.036684
#          Iterations: 7
#          Function evaluations: 454
# Optimization terminated successfully.
#          Current function value: 0.033848
#          Iterations: 7
#          Function evaluations: 456
# Optimization terminated successfully.
#          Current function value: 0.031256
#          Iterations: 7
#          Function evaluations: 444
# Optimization terminated successfully.
#          Current function value: 0.028386
#          Iterations: 7
#          Function evaluations: 453
# Optimization terminated successfully.
#          Current function value: 0.025659
#          Iterations: 7
#          Function evaluations: 455
# Optimization terminated successfully.
#          Current function value: 0.023028
#          Iterations: 7
#          Function evaluations: 446
# Optimization terminated successfully.
#          Current function value: 0.020215
#          Iterations: 7
#          Function evaluations: 451
# Optimization terminated successfully.
#          Current function value: 0.017404
#          Iterations: 7
#          Function evaluations: 479
# Optimization terminated successfully.
#          Current function value: 0.014610
#          Iterations: 7
#          Function evaluations: 453
# Optimization terminated successfully.
#          Current function value: 0.011948
#          Iterations: 7
#          Function evaluations: 459
# Optimization terminated successfully.
#          Current function value: 0.009199
#          Iterations: 7
#          Function evaluations: 442
# Optimization terminated successfully.
#          Current function value: 0.006489
#          Iterations: 7
#          Function evaluations: 454
# Optimization terminated successfully.
#          Current function value: 0.003758
#          Iterations: 8
#          Function evaluations: 523
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 8
#          Function evaluations: 530
# Optimization terminated successfully.
#          Current function value: -0.001626
#          Iterations: 8
#          Function evaluations: 525
# Optimization terminated successfully.
#          Current function value: -0.004315
#          Iterations: 7
#          Function evaluations: 464
# Optimization terminated successfully.
#          Current function value: -0.006864
#          Iterations: 7
#          Function evaluations: 462
# Optimization terminated successfully.
#          Current function value: -0.009510
#          Iterations: 7
#          Function evaluations: 463
# Optimization terminated successfully.
#          Current function value: -0.012180
#          Iterations: 7
#          Function evaluations: 459
# Optimization terminated successfully.
#          Current function value: -0.014762
#          Iterations: 7
#          Function evaluations: 461
# Optimization terminated successfully.
#          Current function value: -0.017360
#          Iterations: 7
#          Function evaluations: 463
# Optimization terminated successfully.
#          Current function value: -0.019864
#          Iterations: 7
#          Function evaluations: 467
# Optimization terminated successfully.
#          Current function value: -0.022472
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: -0.025076
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: -0.027666
#          Iterations: 7
#          Function evaluations: 463
# Optimization terminated successfully.
#          Current function value: -0.030246
#          Iterations: 7
#          Function evaluations: 457
# Optimization terminated successfully.
#          Current function value: -0.032757
#          Iterations: 7
#          Function evaluations: 460
# Optimization terminated successfully.
#          Current function value: -0.035064
#          Iterations: 7
#          Function evaluations: 472
# Optimization terminated successfully.
#          Current function value: -0.037516
#          Iterations: 7
#          Function evaluations: 468
# Optimization terminated successfully.
#          Current function value: -0.040046
#          Iterations: 7
#          Function evaluations: 470
# Optimization terminated successfully.
#          Current function value: -0.042312
#          Iterations: 7
#          Function evaluations: 473
# Optimization terminated successfully.
#          Current function value: -0.044752
#          Iterations: 7
#          Function evaluations: 478
# Optimization terminated successfully.
#          Current function value: -0.047241
#          Iterations: 7
#          Function evaluations: 473
# Optimization terminated successfully.
#          Current function value: -0.049722
#          Iterations: 7
#          Function evaluations: 471
# Optimization terminated successfully.
#          Current function value: -0.052186
#          Iterations: 7
#          Function evaluations: 478
# Optimization terminated successfully.
#          Current function value: -0.054630
#          Iterations: 7
#          Function evaluations: 473
# Optimization terminated successfully.
#          Current function value: -0.057058
#          Iterations: 7
#          Function evaluations: 477
# Optimization terminated successfully.
#          Current function value: -0.059456
#          Iterations: 7
#          Function evaluations: 468
# Optimization terminated successfully.
#          Current function value: -0.061800
#          Iterations: 7
#          Function evaluations: 476
# Optimization terminated successfully.
#          Current function value: -0.064215
#          Iterations: 7
#          Function evaluations: 475
# Optimization terminated successfully.
#          Current function value: -0.066620
#          Iterations: 7
#          Function evaluations: 473
# Optimization terminated successfully.
#          Current function value: -0.068986
#          Iterations: 7
#          Function evaluations: 481
# Optimization terminated successfully.
#          Current function value: -0.071354
#          Iterations: 7
#          Function evaluations: 472
# Optimization terminated successfully.
#          Current function value: -0.073723
#          Iterations: 7
#          Function evaluations: 478
# Optimization terminated successfully.
#          Current function value: -0.076082
#          Iterations: 7
#          Function evaluations: 471
# Optimization terminated successfully.
#          Current function value: -0.078430
#          Iterations: 7
#          Function evaluations: 473
# Optimization terminated successfully.
#          Current function value: -0.080760
#          Iterations: 7
#          Function evaluations: 469
# Optimization terminated successfully.
#          Current function value: -0.083053
#          Iterations: 7
#          Function evaluations: 477
# Optimization terminated successfully.
#          Current function value: -0.085375
#          Iterations: 7
#          Function evaluations: 470
# Optimization terminated successfully.
#          Current function value: -0.087686
#          Iterations: 7
#          Function evaluations: 469
# Optimization terminated successfully.
#          Current function value: -0.089966
#          Iterations: 7
#          Function evaluations: 470
# Optimization terminated successfully.
#          Current function value: -0.092237
#          Iterations: 7
#          Function evaluations: 468
# Optimization terminated successfully.
#          Current function value: -0.094518
#          Iterations: 7
#          Function evaluations: 473
# Optimization terminated successfully.
#          Current function value: -0.096771
#          Iterations: 7
#          Function evaluations: 473
# Optimization terminated successfully.
#          Current function value: -0.099033
#          Iterations: 7
#          Function evaluations: 478
# Optimization terminated successfully.
#          Current function value: -0.101260
#          Iterations: 7
#          Function evaluations: 469
# Optimization terminated successfully.
#          Current function value: -0.103504
#          Iterations: 7
#          Function evaluations: 479
# Optimization terminated successfully.
#          Current function value: -0.105740
#          Iterations: 7
#          Function evaluations: 470

# %%
test_sarima['pred'] = predictions
test_sarima['y_diarrhoea'] = scaler.inverse_transform(test_sarima.diarrhoea.values.reshape(-1,1))
test_sarima['y_pred']= scaler.inverse_transform(test_sarima.pred.values.reshape(-1,1))
test_sarima
# Out:
#             diarrhoea      pred  y_diarrhoea       y_pred
# date1
# 2009-01-15  -0.903025 -1.101191        654.0   -46.912090
# 2009-02-15  -0.964942 -0.764877        435.0  1142.629461
# 2009-03-15  -0.914900 -0.786034        612.0  1067.798696
# 2009-04-15  -0.842805 -0.921239        867.0   589.579334
# 2009-05-15  -0.569975 -0.858908       1832.0   810.041373
# ...               ...       ...          ...          ...
# 2016-09-15  -1.007068 -0.999895        286.0   311.369891
# 2016-10-15  -1.024597 -1.000669        224.0   308.632937
# 2016-11-15  -1.024880 -1.022402        223.0   231.765762
# 2016-12-15  -1.031383 -1.033427        200.0   192.769772
# 2017-01-15  -0.807181 -1.050486        993.0   132.429306
#
# [97 rows x 4 columns]

# %%
y_forecasted = test_sarima.y_pred.values
y_truth = test_sarima.y_diarrhoea.values


# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of SARIMA is {}'.format(mse))
test_sarima[['y_diarrhoea', 'y_pred']].plot(title='SARIMA',figsize=(15,9))
plt.xlabel("Date")
plt.ylabel("Diarrhoea")
plt.show()
# Out:
# The Mean Squared Error of SARIMA is 79868.01397761707

# %% [markdown]
# # LSTM

# %%
def create_dataset(df, previous=1):
    dataX, dataY = [], []
    for i in range(len(df)-previous-1):
        a = df[i:(i+previous), 0]
        dataX.append(a)
        dataY.append(df[i + previous, 0])
    return np.array(dataX), np.array(dataY)

# %%
# Lookback period
lookback = 6
X_train, Y_train = create_dataset(train.values, lookback)
X_test, Y_test = create_dataset(test.values, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

model = tf.keras.Sequential()
model.add(LSTM(12,input_shape=(1, lookback)))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
history=model.fit(X_train, Y_train, epochs=50, batch_size=1, verbose=0)

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

predictions = scaler.inverse_transform(test_pred)
groundtruth = scaler.inverse_transform([Y_test])

mse = ((predictions - groundtruth) ** 2).mean()
print('The Mean Squared Error of LSTM is {}'.format(mse))
# Out:
# The Mean Squared Error of LSTM is 22014.78671604477

# %%
plt.figure(figsize=(15,9))
plt.plot(groundtruth.reshape(-1,1), label='y_diarrhoea')
plt.plot(predictions, label='y_pred')
plt.xlabel("Period")
plt.ylabel("Diarrhoea")
plt.legend()
plt.show()
